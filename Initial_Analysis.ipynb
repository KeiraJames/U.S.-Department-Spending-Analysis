# %% [markdown]
# <h1> Analyze Daily Treasury Statements of Departments that Withdraw & Deposit Cash (by Millions) </h1>

# %%
#import modules
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# <h3> EXAMINING THE FILE </h3>

# %%
#Examine file
initial_file = "Daily_Fed_Budget.csv"
cleaned_file = "Cleaned_Daily_Fed_Budget.csv"

#open files to read from and write to
file = open(initial_file, 'r')
reader = csv.reader(file)

output_file = open(cleaned_file, 'w', newline='')
writer = csv.writer(output_file)

line_number = 1  # Start counting from line 1
removed_rows = []

for row in reader:
    if len(row) == 16:  # Only write rows with exactly 16 fields
        writer.writerow(row)
    else:
        removed_rows.append(row)
        print(f"Line {line_number} has {len(row)} fields and was skipped.")
    
    line_number += 1  # Manually increment the line number
print(removed_rows)
# Out:
# Line 41 has 18 fields and was skipped.
# [['2025-01-24', 'Treasury General Account (TGA)', 'Deposits', 'Taxes - IRS Collected Estate', ' Gift', ' misc', '39', '285', '1182', 'II', 'Deposits and Withdrawals of Operating Cash', '39', '2025', '2', '2025', '1', '01', '24']]

# %%
# import csv file of Deposits and Withdrawals of Operating Cash
file = "Cleaned_Daily_Fed_Budget.csv"
df = pd.read_csv(file)

# %% [markdown]
# <h3> Examine Dataset </h3>

# %%
df.head(1)
# Out:
#   Record Date                 Type of Account Transaction Type  \
# 0  2025-01-24  Treasury General Account (TGA)      Withdrawals
#
#   Transaction Category  Transactions Today  Transactions Month to Date  \
# 0                 NASA                  35                        1109
#
#    Transactions Fiscal Year to Date Table Number  \
# 0                              7452           II
#
#                                    Table Name  Source Line Number  \
# 0  Deposits and Withdrawals of Operating Cash                 167
#
#    Fiscal Year  Fiscal Quarter Number  Calendar Year  Calendar Quarter Number  \
# 0         2025                      2           2025                        1
#
#    Calendar Month Number  Calendar Day Number
# 0                      1                   24

# %%
#I want to view the max rows always
pd.set_option("display.max_rows", None)

# %%
# Broad examination 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Record Date                       144 non-null    object
#  1   Type of Account                   144 non-null    object
#  2   Transaction Type                  144 non-null    object
#  3   Transaction Category              143 non-null    object
#  4   Transactions Today                144 non-null    int64
#  5   Transactions Month to Date        144 non-null    int64
#  6   Transactions Fiscal Year to Date  144 non-null    int64
#  7   Table Number                      144 non-null    object
#  8   Table Name                        144 non-null    object
#  9   Source Line Number                144 non-null    int64
#  10  Fiscal Year                       144 non-null    int64
#  11  Fiscal Quarter Number             144 non-null    int64
#  12  Calendar Year                     144 non-null    int64
#  13  Calendar Quarter Number           144 non-null    int64
#  14  Calendar Month Number             144 non-null    int64
#  15  Calendar Day Number               144 non-null    int64
# dtypes: int64(10), object(6)
# memory usage: 18.1+ KB

# %%
# Check that the entires all have the same date
df['Record Date'].value_counts()
# Out:
# Record Date
# 2025-01-24    144
# Name: count, dtype: int64

# %%
# Check all types of Departments
df['Transaction Category'].value_counts() 

# We have 180 departments that withdraw/deposit
# Out:
# Transaction Category
# TREAS - United States Mint                  2
# DOL - Pension Benefit Guaranty Corp.        2
# HUD - Federal Housing Admin (FHA)           2
# Dept of Interior (DOI) - misc               2
# DOI - Fish and Wildlife and Parks           2
# DOI - Land and Minerals Management          2
# Dept of Justice (DOJ)                       2
# Dept of Labor (DOL) - misc                  2
# Dept of State (DOS)                         2
# DHS - Transportation Security Admn (TSA)    2
# Dept of Treasury (TREAS) - misc             2
# TREAS - Bureau of Engraving and Printing    2
# TREAS - Comptroller of the Currency         2
# TREAS - Federal Financing Bank              2
# Dept of Agriculture (USDA) - misc           2
# Dept of Veterans Affairs (VA)               2
# Dept of Housing & Urban Dev (HUD) - misc    2
# DOI - Water and Science                     2
# Dept of Energy (DOE)                        2
# DoD - Health                                2
# USDA - Federal Crop Insurance Corp Fund     2
# Dept of Homeland Security (DHS) - misc      2
# USDA - Commodity Credit Corporation         2
# DHS - Fed Emergency Mgmt Agency (FEMA)      2
# Dept of Commerce (DOC)                      2
# Dept of Health & Human Serv (HHS) - misc    2
# Dept of Defense (DoD) - misc                2
# Dept of Education (ED)                      2
# DoD - Military Retirement                   1
# Public Debt Cash Issues (Table IIIB)        1
# HHS - Centers for Disease Control (CDC)     1
# USDA - Supp Nutrition Assist Prog (WIC)     1
# HHS - Federal Hospital Insr Trust Fund      1
# HHS - Federal Supple Med Insr Trust Fund    1
# HHS - Grants to States for Medicaid         1
# HHS - Health Resources & Services Admin     1
# DoD - Military Active Duty Pay              1
# State Unemployment Insurance Deposits       1
# USDA - Supp Nutrition Assist Prog (SNAP)    1
# USDA - Other Farm Service                   1
# USDA - Loan Payments                        1
# USDA - Child Nutrition                      1
# United States Postal Service (USPS)         1
# HHS - Marketplace Payments                  1
# US Army Corps of Engineers                  1
# Corporation for Public Broadcasting         1
# Unclassified - Deposits                     1
# HHS - Indian Health Service                 1
# NASA                                        1
# HHS - Medicare Prescription Drugs           1
# HHS - National Institutes of Health         1
# ESF - Economic Recovery Programs            1
# Taxes - Individual Tax Refunds (EFT)        1
# Taxes - Business Tax Refunds (EFT)          1
# TREAS - Pmt to Resolution Funding Corp      1
# TREAS - IRS Refunds for Puerto Rico         1
# TREAS - Claims Judgments and Relief Acts    1
# DOT - Federal Transit Administration        1
# DOT - Federal Railroad Administration       1
# Social Security Admin (SSA) - misc          1
# DOT - Federal Highway Administration        1
# DOT - Federal Aviation Administration       1
# Dept of Transportation (DOT) - misc         1
# DOL - Unemployment Benefits                 1
# DHS - Customs & Border Protection (CBP)     1
# HHS - Temp Assistance for Needy Families    1
# HHS - Payments to States                    1
# HHS - Othr Cent Medicare & Medicaid Serv    1
# HHS - Othr Admin for Children & Families    1
# HHS - Other Public Health Services          1
# SSA - Supplemental Security Income          1
# Int'l Assistance Programs (IAP) - misc      1
# Small Business Administration (SBA)         1
# Taxes - Estate and Gift                     1
# Environmental Protection Agency (EPA)       1
# District of Columbia                        1
# Taxes - Withheld Individual/FICA            1
# Taxes - Railroad Retirement                 1
# Taxes - Non Withheld Ind/SECA Other         1
# Taxes - Non Withheld Ind/SECA Electronic    1
# Taxes - Miscellaneous Excise                1
# Taxes - Federal Unemployment (FUTA)         1
# Taxes - Corporate Income                    1
# Federal Communications Commission (FCC)     1
# TREAS - GSE Proceeds                        1
# Dept of Transportation (DOT)                1
# DOI - Gas and Oil Lease Sales Proceeds      1
# DHS - Seized Assets                         1
# DHS - Customs and Certain Excise Taxes      1
# HHS - Medicare Premiums                     1
# HHS - Marketplace Receipts                  1
# USDA - Loan Repayments                      1
# Export-Import Bank                          1
# FCC - Universal Service Fund                1
# Securities and Exchange Commission (SEC)    1
# Judicial Branch - Courts                    1
# RRB - Unemployment Insurance                1
# RRB - Natl Railroad Retirement Inv Trust    1
# OPM - Federal Employee Insurance Receipt    1
# Office of Personnel Mgmt (OPM) - misc       1
# National Science Foundation (NSF)           1
# National Credit Union Admin (NCUA)          1
# Legislative Branch - Library of Congress    1
# Legislative Branch - misc                   1
# IAP - US Int'l Devlop Finance Corp (DFC)    1
# Federal Deposit Insurance Corp (FDIC)       1
# IAP - Foreign Military Sales                1
# IAP - Agency for Int'l Development (AID)    1
# International Monetary Fund (IMF)           1
# Independent Agencies - misc                 1
# General Services Administration (GSA)       1
# Federal Trade Commission (FTC)              1
# Federal Retirement Thrift Savings Plan      1
# Federal Reserve Earnings                    1
# VA - Benefits                               1
# Name: count, dtype: int64

# %% [markdown]
# <h1> Withdrawals </h1>

# %%
# How frequently do we withdraw or deposit?
df['Transaction Type'].value_counts() 

# We withdraw more than we deposit
# Out:
# Transaction Type
# Deposits       79
# Withdrawals    65
# Name: count, dtype: int64

# %%
# How much do we withdraw, daily, monthly, fiscal ytd?

#Grab sections of the df that align with withdrawals
withdrawals_df = df[ (df['Transaction Type'] == 'Withdrawals')  &  (df['Type of Account'] == 'Treasury General Account (TGA)')]
withdrawals_df["Transaction Type"].value_counts()
# Out:
# Transaction Type
# Withdrawals    65
# Name: count, dtype: int64

# %%
#**********************************************FISCAL YTD*******************************************************

# Get total amount in $ of transactions for fiscal ytd column
ytd_withdrawals = withdrawals_df['Transactions Fiscal Year to Date'].sum()
print('Total sum of transactions fiscal ytd: $' , ytd_withdrawals)

# Show the breakdown per department. In percentages, which department withdraws the most
( (withdrawals_df.groupby('Transaction Category')['Transactions Fiscal Year to Date'].sum()  /  ytd_withdrawals ) *100).sort_values(ascending=False).head(5)
# Out:
# Total sum of transactions fiscal ytd: $ 1399652
# Transaction Category
# HHS - Grants to States for Medicaid         14.283693
# HHS - Federal Supple Med Insr Trust Fund    12.611992
# Dept of Defense (DoD) - misc                10.876775
# HHS - Federal Hospital Insr Trust Fund       9.441275
# Dept of Education (ED)                       5.395698
# Name: Transactions Fiscal Year to Date, dtype: float64

# %%
#**********************************************Month to Date*******************************************************

# Get total amount in $ of transactions for moth to date column
mtd_withdrawals = withdrawals_df['Transactions Month to Date'].sum()
print('Total sum of transactions month to date: $' , mtd_withdrawals)

# Show the breakdown per department. In percentages, which department withdraws the most
( (withdrawals_df.groupby('Transaction Category')['Transactions Month to Date'].sum()  /  mtd_withdrawals ) * 100).sort_values(ascending=False).head(5)
# Out:
# Total sum of transactions month to date: $ 281232
# Transaction Category
# HHS - Grants to States for Medicaid         14.697830
# HHS - Federal Supple Med Insr Trust Fund    13.905245
# HHS - Federal Hospital Insr Trust Fund      10.534363
# Dept of Education (ED)                      10.099846
# Dept of Defense (DoD) - misc                 9.792271
# Name: Transactions Month to Date, dtype: float64

# %%
#**********************************************Daily*******************************************************

# Get total amount in $ of transactions for month to date column
today_withdrawals = withdrawals_df['Transactions Today'].sum()
print('Total sum of transactions today: $' , today_withdrawals)

# Show the breakdown per department. In percentages, which department withdraws the most
( (withdrawals_df.groupby('Transaction Category')['Transactions Today'].sum()  /  today_withdrawals ) * 100).sort_values(ascending=False).head(5)
# Out:
# Total sum of transactions today: $ 11671
# Transaction Category
# Dept of Defense (DoD) - misc                20.272470
# Dept of Education (ED)                      14.060492
# HHS - Federal Hospital Insr Trust Fund       9.279411
# HHS - Grants to States for Medicaid          7.737126
# HHS - Federal Supple Med Insr Trust Fund     7.600034
# Name: Transactions Today, dtype: float64

# %% [markdown]
# <h1> Deposits </h1>

# %%
df['Transaction Type'].value_counts()
# Out:
# Transaction Type
# Deposits       79
# Withdrawals    65
# Name: count, dtype: int64

# %%
# DF for deposits
deposits_df = df[ (df['Transaction Type']=='Deposits')  &  (df['Type of Account']=='Treasury General Account (TGA)') ]
deposits_df['Transaction Type'].value_counts()
# Out:
# Transaction Type
# Deposits    78
# Name: count, dtype: int64

# %%
#**********************************************FISCAL YTD*******************************************************
ytd_deposits = deposits_df['Transactions Fiscal Year to Date'].sum()
print("Total sum of ytd deposits = $", ytd_deposits)

( ( deposits_df.groupby('Transaction Category')['Transactions Fiscal Year to Date'].sum() / ytd_deposits ) * 100).sort_values(ascending=False).head(5)
# Out:
# Total sum of ytd deposits = $ 11737113
# Transaction Category
# Public Debt Cash Issues (Table IIIB)        85.506521
# Taxes - Withheld Individual/FICA             9.228010
# Taxes - Corporate Income                     1.150777
# Taxes - Non Withheld Ind/SECA Electronic     1.088794
# Taxes - Non Withheld Ind/SECA Other          0.728723
# Name: Transactions Fiscal Year to Date, dtype: float64

# %%
#**********************************************Month to date*******************************************************
mtd_deposits = deposits_df['Transactions Month to Date'].sum()
print("Total sum of ytd deposits = $", mtd_deposits)

( ( deposits_df.groupby('Transaction Category')['Transactions Month to Date'].sum() / mtd_deposits ) * 100).sort_values(ascending=False).head(5)
# Out:
# Total sum of ytd deposits = $ 2435615
# Transaction Category
# Public Debt Cash Issues (Table IIIB)        82.283284
# Taxes - Withheld Individual/FICA             9.773753
# Taxes - Non Withheld Ind/SECA Electronic     3.129559
# Taxes - Non Withheld Ind/SECA Other          2.011689
# Taxes - Corporate Income                     0.848081
# Name: Transactions Month to Date, dtype: float64

# %%
#**********************************************Daily*******************************************************
daily_deposits = deposits_df['Transactions Today'].sum()
print("Total sum of ytd deposits = $", daily_deposits)

( ( deposits_df.groupby('Transaction Category')['Transactions Today'].sum() / daily_deposits ) * 100).sort_values(ascending=False).head(5)
# Out:
# Total sum of ytd deposits = $ 25283
# Transaction Category
# Taxes - Non Withheld Ind/SECA Other         47.423170
# Taxes - Withheld Individual/FICA            33.030099
# Public Debt Cash Issues (Table IIIB)         6.545900
# Taxes - Non Withheld Ind/SECA Electronic     2.195151
# Taxes - Corporate Income                     1.566270
# Name: Transactions Today, dtype: float64

# %%
# FOUND discrepancies between actual sum of deposits and reported sum of deposits
reported_dytd_sum = df[df['Type of Account']== 'Treasury General Account Total Deposits']['Transactions Fiscal Year to Date'].sum()

print("Reported deposit sum fytd: $", reported_dytd_sum)
print("What I found for deposit sum fytd: $", ytd_deposits)
print("Discrepancy: ", (reported_dytd_sum - ytd_deposits), '\n')

reported_dmtd_sum = df[df['Type of Account']== 'Treasury General Account Total Deposits']['Transactions Month to Date'].sum()

print("Reported deposit sum mtd: $", reported_dmtd_sum)
print("What I found for deposit sum mtd: $", mtd_deposits)
print("Discrepancy: ", (reported_dmtd_sum - mtd_deposits), '\n')

reported_dday_sum = df[df['Type of Account']== 'Treasury General Account Total Deposits']['Transactions Today'].sum()

print("Reported deposit sum day: $", reported_dday_sum)
print("What I found for deposit sum day: $",daily_deposits)
print("Discrepancy: ", (reported_dday_sum - daily_deposits))
# Out:
# Reported deposit sum fytd: $ 11738297
# What I found for deposit sum fytd: $ 11737113
# Discrepancy:  1184
#
# Reported deposit sum mtd: $ 2435898
# What I found for deposit sum mtd: $ 2435615
# Discrepancy:  283
#
# Reported deposit sum day: $ 25320
# What I found for deposit sum day: $ 25283
# Discrepancy:  37

# %% [markdown]
# They deposited less than they said they did.

# %%
# FOUND discrepancies between actual sum of withdrawals
reported_ytd_sum = df[df['Type of Account']== 'Treasury General Account Total Withdrawals']['Transactions Fiscal Year to Date'].sum()

print("Reported withdrawals sum fytd: $", reported_ytd_sum)
print("What I found for withdrawals sum fytd: $", ytd_withdrawals)
print("Discrepancy: ", (reported_ytd_sum - ytd_withdrawals), '\n')

reported_mtd_sum = df[df['Type of Account']== 'Treasury General Account Total Withdrawals']['Transactions Month to Date'].sum()

print("Reported withdrawals sum mtd: $", reported_mtd_sum)
print("What I found for withdrawals sum mtd: $", mtd_withdrawals)
print("Discrepancy: ", (reported_mtd_sum - mtd_withdrawals), '\n')

reported_day_sum = df[df['Type of Account']== 'Treasury General Account Total Withdrawals']['Transactions Today'].sum()

print("Reported withdrawals sum day: $", reported_day_sum)
print("What I found for withdrawals sum day: $",today_withdrawals)
print("Discrepancy: ", (reported_day_sum - today_withdrawals))
# Out:
# Reported withdrawals sum fytd: $ 0
# What I found for withdrawals sum fytd: $ 1399652
# Discrepancy:  -1399652
#
# Reported withdrawals sum mtd: $ 0
# What I found for withdrawals sum mtd: $ 281232
# Discrepancy:  -281232
#
# Reported withdrawals sum day: $ 0
# What I found for withdrawals sum day: $ 11671
# Discrepancy:  -11671

# %% [markdown]
# They withdrew $1 more than they said they did.

# %%
# Now lets look at that row we got rid of earlier:
print(removed_rows)

ddf = pd.DataFrame(removed_rows)
ddf
# Out:
# [['2025-01-24', 'Treasury General Account (TGA)', 'Deposits', 'Taxes - IRS Collected Estate', ' Gift', ' misc', '39', '285', '1182', 'II', 'Deposits and Withdrawals of Operating Cash', '39', '2025', '2', '2025', '1', '01', '24']]
#            0                               1         2   \
# 0  2025-01-24  Treasury General Account (TGA)  Deposits
#
#                              3      4      5   6    7     8   9   \
# 0  Taxes - IRS Collected Estate   Gift   misc  39  285  1182  II
#
#                                            10  11    12 13    14 15  16  17
# 0  Deposits and Withdrawals of Operating Cash  39  2025  2  2025  1  01  24

# %%
df.head(1)
# Out:
#   Record Date                 Type of Account Transaction Type  \
# 0  2025-01-24  Treasury General Account (TGA)      Withdrawals
#
#   Transaction Category  Transactions Today  Transactions Month to Date  \
# 0                 NASA                  35                        1109
#
#    Transactions Fiscal Year to Date Table Number  \
# 0                              7452           II
#
#                                    Table Name  Source Line Number  \
# 0  Deposits and Withdrawals of Operating Cash                 167
#
#    Fiscal Year  Fiscal Quarter Number  Calendar Year  Calendar Quarter Number  \
# 0         2025                      2           2025                        1
#
#    Calendar Month Number  Calendar Day Number
# 0                      1                   24

# %%
#It seems like the rows nearly match up, the only discrepancy is column 4 and 5. Let's drop those and readd the row to the original dataframr

ddf = ddf.drop(columns=[4,5])
ddf
# Out:
#            0                               1         2   \
# 0  2025-01-24  Treasury General Account (TGA)  Deposits
#
#                              3   6    7     8   9   \
# 0  Taxes - IRS Collected Estate  39  285  1182  II
#
#                                            10  11    12 13    14 15  16  17
# 0  Deposits and Withdrawals of Operating Cash  39  2025  2  2025  1  01  24

# %%
# assign the column names of df to ddf
ddf.columns = df.columns

# combine the dataframes vertically (stacked)
df_combined = pd.concat([df, ddf], axis=0, ignore_index=True)
df_combined.tail()
# Out:
#     Record Date                 Type of Account Transaction Type  \
# 140  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 141  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 142  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 143  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 144  2025-01-24  Treasury General Account (TGA)         Deposits
#
#                      Transaction Category Transactions Today  \
# 140  Taxes - Individual Tax Refunds (EFT)                  3
# 141      ESF - Economic Recovery Programs                  0
# 142         Dept of Veterans Affairs (VA)                283
# 143                         VA - Benefits                155
# 144          Taxes - IRS Collected Estate                 39
#
#     Transactions Month to Date Transactions Fiscal Year to Date Table Number  \
# 140                        140                            20562           II
# 141                         50                            -1143           II
# 142                       6666                            33401           II
# 143                       1268                            64823           II
# 144                        285                             1182           II
#
#                                      Table Name Source Line Number  \
# 140  Deposits and Withdrawals of Operating Cash                142
# 141  Deposits and Withdrawals of Operating Cash                143
# 142  Deposits and Withdrawals of Operating Cash                144
# 143  Deposits and Withdrawals of Operating Cash                145
# 144  Deposits and Withdrawals of Operating Cash                 39
#
#     Fiscal Year Fiscal Quarter Number Calendar Year Calendar Quarter Number  \
# 140        2025                     2          2025                       1
# 141        2025                     2          2025                       1
# 142        2025                     2          2025                       1
# 143        2025                     2          2025                       1
# 144        2025                     2          2025                       1
#
#     Calendar Month Number Calendar Day Number
# 140                     1                  24
# 141                     1                  24
# 142                     1                  24
# 143                     1                  24
# 144                    01                  24

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Record Date                       145 non-null    object
#  1   Type of Account                   145 non-null    object
#  2   Transaction Type                  145 non-null    object
#  3   Transaction Category              144 non-null    object
#  4   Transactions Today                145 non-null    object
#  5   Transactions Month to Date        145 non-null    object
#  6   Transactions Fiscal Year to Date  145 non-null    object
#  7   Table Number                      145 non-null    object
#  8   Table Name                        145 non-null    object
#  9   Source Line Number                145 non-null    object
#  10  Fiscal Year                       145 non-null    object
#  11  Fiscal Quarter Number             145 non-null    object
#  12  Calendar Year                     145 non-null    object
#  13  Calendar Quarter Number           145 non-null    object
#  14  Calendar Month Number             145 non-null    object
#  15  Calendar Day Number               145 non-null    object
# dtypes: object(16)
# memory usage: 18.3+ KB

# %%
# NOW, we should fix that discrepancy we sae



df_combined['Transactions Fiscal Year to Date'] = df_combined['Transactions Fiscal Year to Date'].astype(int)

df_combined['Transactions Month to Date'] = df_combined['Transactions Month to Date'].astype(int)


df_combined['Transactions Today'] = df_combined['Transactions Today'].astype(int)
new_deposits_df = df_combined[ (df_combined['Transaction Type']=='Deposits')  &  (df_combined['Type of Account']=='Treasury General Account (TGA)') ]

new_ytd_deposits = new_deposits_df['Transactions Fiscal Year to Date'].sum()
new_mtd_deposits = new_deposits_df['Transactions Month to Date'].sum()
new_daily_deposits = new_deposits_df['Transactions Today'].sum()

# %%
reported_dytd_sum = df[df['Type of Account']== 'Treasury General Account Total Deposits']['Transactions Fiscal Year to Date'].sum()

print("Reported deposit sum fytd: $", reported_dytd_sum)
print("NEW What I found for deposit sum fytd: $", new_ytd_deposits)
print("Discrepancy: ", (reported_dytd_sum - new_ytd_deposits), '\n')

reported_dmtd_sum = df[df['Type of Account']== 'Treasury General Account Total Deposits']['Transactions Month to Date'].sum()

print("Reported deposit sum mtd: $", reported_dmtd_sum)
print("NEW What I found for deposit sum mtd: $", new_mtd_deposits) 
print("Discrepancy: ", (reported_dmtd_sum - new_mtd_deposits), '\n')

reported_dday_sum = df[df['Type of Account']== 'Treasury General Account Total Deposits']['Transactions Today'].sum()

print("Reported deposit sum day: $", reported_dday_sum)
print("NEW What I found for deposit sum day: $",new_daily_deposits )
print("Discrepancy: ", (reported_dday_sum - new_daily_deposits))
# Out:
# Reported deposit sum fytd: $ 11738297
# NEW What I found for deposit sum fytd: $ 11738295
# Discrepancy:  2
#
# Reported deposit sum mtd: $ 2435898
# NEW What I found for deposit sum mtd: $ 2435900
# Discrepancy:  -2
#
# Reported deposit sum day: $ 25320
# NEW What I found for deposit sum day: $ 25322
# Discrepancy:  -2

# %%
df['Type of Account'].value_counts()
# Out:
# Type of Account
# Treasury General Account (TGA)             143
# Treasury General Account Total Deposits      1
# Name: count, dtype: int64

# %%
df[df['Type of Account']== 'Treasury General Account (TGA)']

df[df['Type of Account']== 'Treasury General Account Total Deposits']
#df[df['Type of Account']== 'Treasury General Account Total Withdrawals']
# Out:
#    Record Date                          Type of Account Transaction Type  \
# 79  2025-01-24  Treasury General Account Total Deposits         Deposits
#
#    Transaction Category  Transactions Today  Transactions Month to Date  \
# 79                  NaN               25320                     2435898
#
#     Transactions Fiscal Year to Date Table Number  \
# 79                          11738297           II
#
#                                     Table Name  Source Line Number  \
# 79  Deposits and Withdrawals of Operating Cash                  81
#
#     Fiscal Year  Fiscal Quarter Number  Calendar Year  \
# 79         2025                      2           2025
#
#     Calendar Quarter Number  Calendar Month Number  Calendar Day Number
# 79                        1                      1                   24

# %%
new_output_f = "Final_Fed_Budget_Cleaned.csv"
df_combined.to_csv(new_output_f, index=False)

# %%
df.columns = [name.replace(" ", "_") for name in df.columns]

df.columns
# Out:
# Index(['Record_Date', 'Type_of_Account', 'Transaction_Type',
#        'Transaction_Category', 'Transactions_Today',
#        'Transactions_Month_to_Date', 'Transactions_Fiscal_Year_to_Date',
#        'Table_Number', 'Table_Name', 'Source_Line_Number', 'Fiscal_Year',
#        'Fiscal_Quarter_Number', 'Calendar_Year', 'Calendar_Quarter_Number',
#        'Calendar_Month_Number', 'Calendar_Day_Number'],
#       dtype='object')

# %%
my_df = df_combined
my_df.head(4)
# Out:
#   Record Date                 Type of Account Transaction Type  \
# 0  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 1  2025-01-24  Treasury General Account (TGA)         Deposits
# 2  2025-01-24  Treasury General Account (TGA)         Deposits
# 3  2025-01-24  Treasury General Account (TGA)         Deposits
#
#                       Transaction Category  Transactions Today  \
# 0                                     NASA                  35
# 1        Dept of Agriculture (USDA) - misc                  19
# 2      USDA - Commodity Credit Corporation                  47
# 3  USDA - Federal Crop Insurance Corp Fund                   0
#
#    Transactions Month to Date  Transactions Fiscal Year to Date Table Number  \
# 0                        1109                              7452           II
# 1                         270                              1202           II
# 2                         573                              2147           II
# 3                           1                                18           II
#
#                                    Table Name Source Line Number Fiscal Year  \
# 0  Deposits and Withdrawals of Operating Cash                167        2025
# 1  Deposits and Withdrawals of Operating Cash                  1        2025
# 2  Deposits and Withdrawals of Operating Cash                  2        2025
# 3  Deposits and Withdrawals of Operating Cash                  3        2025
#
#   Fiscal Quarter Number Calendar Year Calendar Quarter Number  \
# 0                     2          2025                       1
# 1                     2          2025                       1
# 2                     2          2025                       1
# 3                     2          2025                       1
#
#   Calendar Month Number Calendar Day Number
# 0                     1                  24
# 1                     1                  24
# 2                     1                  24
# 3                     1                  24

# %%
# Find departments that deposit the most, and departments that withdraw the most
withd_df = my_df[ (my_df['Transaction Type'] == 'Withdrawals')  &  ((my_df['Type of Account'] == 'Treasury General Account (TGA)'))]
withd_df

withd_total = withd_df['Transactions Fiscal Year to Date'].sum()

temp_w = ( (withd_df.groupby('Transaction Category')['Transactions Fiscal Year to Date'].sum() / withd_total ) * 100).sort_values(ascending=False)

# %%
temp_w
# Out:
# Transaction Category
# HHS - Grants to States for Medicaid         14.283693
# HHS - Federal Supple Med Insr Trust Fund    12.611992
# Dept of Defense (DoD) - misc                10.876775
# HHS - Federal Hospital Insr Trust Fund       9.441275
# Dept of Education (ED)                       5.395698
# VA - Benefits                                4.631366
# HHS - Medicare Prescription Drugs            3.456073
# HHS - Marketplace Payments                   2.950448
# USDA - Supp Nutrition Assist Prog (SNAP)     2.530272
# DoD - Military Active Duty Pay               2.408956
# Dept of Veterans Affairs (VA)                2.386379
# TREAS - Federal Financing Bank               2.299357
# Dept of Housing & Urban Dev (HUD) - misc     1.963059
# DoD - Military Retirement                    1.678203
# DHS - Fed Emergency Mgmt Agency (FEMA)       1.535453
# HHS - Othr Cent Medicare & Medicaid Serv     1.489799
# DOT - Federal Highway Administration         1.470294
# Taxes - Individual Tax Refunds (EFT)         1.469079
# Dept of Energy (DOE)                         1.441430
# HHS - National Institutes of Health          0.996462
# DOL - Unemployment Benefits                  0.856356
# USDA - Federal Crop Insurance Corp Fund      0.822919
# USDA - Child Nutrition                       0.757188
# Dept of Agriculture (USDA) - misc            0.754616
# DoD - Health                                 0.673953
# HHS - Payments to States                     0.647804
# HHS - Othr Admin for Children & Families     0.636658
# USDA - Commodity Credit Corporation          0.585360
# Dept of Justice (DOJ)                        0.579287
# Dept of Commerce (DOC)                       0.561354
# NASA                                         0.532418
# Dept of State (DOS)                          0.525059
# DOT - Federal Transit Administration         0.519415
# Dept of Labor (DOL) - misc                   0.410674
# Dept of Interior (DOI) - misc                0.382667
# HHS - Temp Assistance for Needy Families     0.381238
# Dept of Homeland Security (DHS) - misc       0.377522
# HUD - Federal Housing Admin (FHA)            0.371092
# HHS - Centers for Disease Control (CDC)      0.347515
# HHS - Indian Health Service                  0.328510
# Dept of Treasury (TREAS) - misc              0.328224
# USDA - Loan Payments                         0.320080
# HHS - Health Resources & Services Admin      0.317579
# DOT - Federal Aviation Administration        0.295502
# DOL - Pension Benefit Guaranty Corp.         0.272068
# Taxes - Business Tax Refunds (EFT)           0.256064
# DHS - Customs & Border Protection (CBP)      0.254420
# HHS - Other Public Health Services           0.246347
# Dept of Health & Human Serv (HHS) - misc     0.238345
# USDA - Supp Nutrition Assist Prog (WIC)      0.176330
# DOI - Fish and Wildlife and Parks            0.133462
# TREAS - Claims Judgments and Relief Acts     0.126103
# DOT - Federal Railroad Administration        0.119172
# Dept of Transportation (DOT) - misc          0.117815
# DOI - Water and Science                      0.101525
# TREAS - United States Mint                   0.099310
# DOI - Land and Minerals Management           0.080591
# DHS - Transportation Security Admn (TSA)     0.060444
# USDA - Other Farm Service                    0.053442
# Corporation for Public Broadcasting          0.038224
# TREAS - Pmt to Resolution Funding Corp       0.032865
# TREAS - IRS Refunds for Puerto Rico          0.022791
# TREAS - Bureau of Engraving and Printing     0.014361
# TREAS - Comptroller of the Currency          0.008931
# ESF - Economic Recovery Programs            -0.081663
# Name: Transactions Fiscal Year to Date, dtype: float64

# %%
dep_df = my_df[ (my_df['Transaction Type'] == 'Deposits')  &  ((my_df['Type of Account'] == 'Treasury General Account (TGA)'))]
dep_df

dep_total = dep_df['Transactions Fiscal Year to Date'].sum()

temp_d = ((dep_df.groupby('Transaction Category')['Transactions Fiscal Year to Date'].sum() / dep_total) * 100).sort_values(ascending=False)
temp_d.shape
# Out:
# (79,)

# %%
df_w = pd.DataFrame(temp_w)
df_w.columns = [['Withdrawal Percentage by Fiscal YTD']]
df_w

df_d = pd.DataFrame(temp_d)
df_d.columns = [['Deposit Percentage by Fiscal YTD']]
df_d

a = pd.concat([df_w, df_d], axis=1, ignore_index=False)
a.shape 
a
my_df['Transaction Category'].value_counts()
final_df = (pd.merge(my_df, a, on='Transaction Category', how='inner'))
final_df

df_w
# Out:
#                                          Withdrawal Percentage by Fiscal YTD
# Transaction Category
# HHS - Grants to States for Medicaid                                14.283693
# HHS - Federal Supple Med Insr Trust Fund                           12.611992
# Dept of Defense (DoD) - misc                                       10.876775
# HHS - Federal Hospital Insr Trust Fund                              9.441275
# Dept of Education (ED)                                              5.395698
# VA - Benefits                                                       4.631366
# HHS - Medicare Prescription Drugs                                   3.456073
# HHS - Marketplace Payments                                          2.950448
# USDA - Supp Nutrition Assist Prog (SNAP)                            2.530272
# DoD - Military Active Duty Pay                                      2.408956
# Dept of Veterans Affairs (VA)                                       2.386379
# TREAS - Federal Financing Bank                                      2.299357
# Dept of Housing & Urban Dev (HUD) - misc                            1.963059
# DoD - Military Retirement                                           1.678203
# DHS - Fed Emergency Mgmt Agency (FEMA)                              1.535453
# HHS - Othr Cent Medicare & Medicaid Serv                            1.489799
# DOT - Federal Highway Administration                                1.470294
# Taxes - Individual Tax Refunds (EFT)                                1.469079
# Dept of Energy (DOE)                                                1.441430
# HHS - National Institutes of Health                                 0.996462
# DOL - Unemployment Benefits                                         0.856356
# USDA - Federal Crop Insurance Corp Fund                             0.822919
# USDA - Child Nutrition                                              0.757188
# Dept of Agriculture (USDA) - misc                                   0.754616
# DoD - Health                                                        0.673953
# HHS - Payments to States                                            0.647804
# HHS - Othr Admin for Children & Families                            0.636658
# USDA - Commodity Credit Corporation                                 0.585360
# Dept of Justice (DOJ)                                               0.579287
# Dept of Commerce (DOC)                                              0.561354
# NASA                                                                0.532418
# Dept of State (DOS)                                                 0.525059
# DOT - Federal Transit Administration                                0.519415
# Dept of Labor (DOL) - misc                                          0.410674
# Dept of Interior (DOI) - misc                                       0.382667
# HHS - Temp Assistance for Needy Families                            0.381238
# Dept of Homeland Security (DHS) - misc                              0.377522
# HUD - Federal Housing Admin (FHA)                                   0.371092
# HHS - Centers for Disease Control (CDC)                             0.347515
# HHS - Indian Health Service                                         0.328510
# Dept of Treasury (TREAS) - misc                                     0.328224
# USDA - Loan Payments                                                0.320080
# HHS - Health Resources & Services Admin                             0.317579
# DOT - Federal Aviation Administration                               0.295502
# DOL - Pension Benefit Guaranty Corp.                                0.272068
# Taxes - Business Tax Refunds (EFT)                                  0.256064
# DHS - Customs & Border Protection (CBP)                             0.254420
# HHS - Other Public Health Services                                  0.246347
# Dept of Health & Human Serv (HHS) - misc                            0.238345
# USDA - Supp Nutrition Assist Prog (WIC)                             0.176330
# DOI - Fish and Wildlife and Parks                                   0.133462
# TREAS - Claims Judgments and Relief Acts                            0.126103
# DOT - Federal Railroad Administration                               0.119172
# Dept of Transportation (DOT) - misc                                 0.117815
# DOI - Water and Science                                             0.101525
# TREAS - United States Mint                                          0.099310
# DOI - Land and Minerals Management                                  0.080591
# DHS - Transportation Security Admn (TSA)                            0.060444
# USDA - Other Farm Service                                           0.053442
# Corporation for Public Broadcasting                                 0.038224
# TREAS - Pmt to Resolution Funding Corp                              0.032865
# TREAS - IRS Refunds for Puerto Rico                                 0.022791
# TREAS - Bureau of Engraving and Printing                            0.014361
# TREAS - Comptroller of the Currency                                 0.008931
# ESF - Economic Recovery Programs                                   -0.081663

# %%
b = "output.csv"
final_df.to_csv(b, index=False)
final_df
# Out:
#     Record Date                 Type of Account Transaction Type  \
# 0    2025-01-24  Treasury General Account (TGA)      Withdrawals
# 1    2025-01-24  Treasury General Account (TGA)         Deposits
# 2    2025-01-24  Treasury General Account (TGA)         Deposits
# 3    2025-01-24  Treasury General Account (TGA)         Deposits
# 4    2025-01-24  Treasury General Account (TGA)         Deposits
# 5    2025-01-24  Treasury General Account (TGA)         Deposits
# 6    2025-01-24  Treasury General Account (TGA)         Deposits
# 7    2025-01-24  Treasury General Account (TGA)         Deposits
# 8    2025-01-24  Treasury General Account (TGA)         Deposits
# 9    2025-01-24  Treasury General Account (TGA)         Deposits
# 10   2025-01-24  Treasury General Account (TGA)         Deposits
# 11   2025-01-24  Treasury General Account (TGA)         Deposits
# 12   2025-01-24  Treasury General Account (TGA)         Deposits
# 13   2025-01-24  Treasury General Account (TGA)         Deposits
# 14   2025-01-24  Treasury General Account (TGA)         Deposits
# 15   2025-01-24  Treasury General Account (TGA)         Deposits
# 16   2025-01-24  Treasury General Account (TGA)         Deposits
# 17   2025-01-24  Treasury General Account (TGA)         Deposits
# 18   2025-01-24  Treasury General Account (TGA)         Deposits
# 19   2025-01-24  Treasury General Account (TGA)         Deposits
# 20   2025-01-24  Treasury General Account (TGA)         Deposits
# 21   2025-01-24  Treasury General Account (TGA)         Deposits
# 22   2025-01-24  Treasury General Account (TGA)         Deposits
# 23   2025-01-24  Treasury General Account (TGA)         Deposits
# 24   2025-01-24  Treasury General Account (TGA)         Deposits
# 25   2025-01-24  Treasury General Account (TGA)         Deposits
# 26   2025-01-24  Treasury General Account (TGA)         Deposits
# 27   2025-01-24  Treasury General Account (TGA)         Deposits
# 28   2025-01-24  Treasury General Account (TGA)         Deposits
# 29   2025-01-24  Treasury General Account (TGA)         Deposits
# 30   2025-01-24  Treasury General Account (TGA)         Deposits
# 31   2025-01-24  Treasury General Account (TGA)         Deposits
# 32   2025-01-24  Treasury General Account (TGA)         Deposits
# 33   2025-01-24  Treasury General Account (TGA)         Deposits
# 34   2025-01-24  Treasury General Account (TGA)         Deposits
# 35   2025-01-24  Treasury General Account (TGA)         Deposits
# 36   2025-01-24  Treasury General Account (TGA)         Deposits
# 37   2025-01-24  Treasury General Account (TGA)         Deposits
# 38   2025-01-24  Treasury General Account (TGA)         Deposits
# 39   2025-01-24  Treasury General Account (TGA)         Deposits
# 40   2025-01-24  Treasury General Account (TGA)         Deposits
# 41   2025-01-24  Treasury General Account (TGA)         Deposits
# 42   2025-01-24  Treasury General Account (TGA)         Deposits
# 43   2025-01-24  Treasury General Account (TGA)         Deposits
# 44   2025-01-24  Treasury General Account (TGA)         Deposits
# 45   2025-01-24  Treasury General Account (TGA)         Deposits
# 46   2025-01-24  Treasury General Account (TGA)         Deposits
# 47   2025-01-24  Treasury General Account (TGA)         Deposits
# 48   2025-01-24  Treasury General Account (TGA)         Deposits
# 49   2025-01-24  Treasury General Account (TGA)         Deposits
# 50   2025-01-24  Treasury General Account (TGA)         Deposits
# 51   2025-01-24  Treasury General Account (TGA)         Deposits
# 52   2025-01-24  Treasury General Account (TGA)         Deposits
# 53   2025-01-24  Treasury General Account (TGA)         Deposits
# 54   2025-01-24  Treasury General Account (TGA)         Deposits
# 55   2025-01-24  Treasury General Account (TGA)         Deposits
# 56   2025-01-24  Treasury General Account (TGA)         Deposits
# 57   2025-01-24  Treasury General Account (TGA)         Deposits
# 58   2025-01-24  Treasury General Account (TGA)         Deposits
# 59   2025-01-24  Treasury General Account (TGA)         Deposits
# 60   2025-01-24  Treasury General Account (TGA)         Deposits
# 61   2025-01-24  Treasury General Account (TGA)         Deposits
# 62   2025-01-24  Treasury General Account (TGA)         Deposits
# 63   2025-01-24  Treasury General Account (TGA)         Deposits
# 64   2025-01-24  Treasury General Account (TGA)         Deposits
# 65   2025-01-24  Treasury General Account (TGA)         Deposits
# 66   2025-01-24  Treasury General Account (TGA)         Deposits
# 67   2025-01-24  Treasury General Account (TGA)         Deposits
# 68   2025-01-24  Treasury General Account (TGA)         Deposits
# 69   2025-01-24  Treasury General Account (TGA)         Deposits
# 70   2025-01-24  Treasury General Account (TGA)         Deposits
# 71   2025-01-24  Treasury General Account (TGA)         Deposits
# 72   2025-01-24  Treasury General Account (TGA)         Deposits
# 73   2025-01-24  Treasury General Account (TGA)         Deposits
# 74   2025-01-24  Treasury General Account (TGA)         Deposits
# 75   2025-01-24  Treasury General Account (TGA)         Deposits
# 76   2025-01-24  Treasury General Account (TGA)         Deposits
# 77   2025-01-24  Treasury General Account (TGA)         Deposits
# 78   2025-01-24  Treasury General Account (TGA)         Deposits
# 79   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 80   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 81   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 82   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 83   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 84   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 85   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 86   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 87   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 88   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 89   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 90   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 91   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 92   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 93   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 94   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 95   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 96   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 97   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 98   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 99   2025-01-24  Treasury General Account (TGA)      Withdrawals
# 100  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 101  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 102  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 103  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 104  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 105  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 106  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 107  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 108  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 109  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 110  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 111  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 112  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 113  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 114  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 115  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 116  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 117  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 118  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 119  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 120  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 121  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 122  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 123  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 124  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 125  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 126  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 127  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 128  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 129  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 130  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 131  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 132  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 133  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 134  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 135  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 136  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 137  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 138  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 139  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 140  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 141  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 142  2025-01-24  Treasury General Account (TGA)      Withdrawals
# 143  2025-01-24  Treasury General Account (TGA)         Deposits
#
#                          Transaction Category  Transactions Today  \
# 0                                        NASA                  35
# 1           Dept of Agriculture (USDA) - misc                  19
# 2         USDA - Commodity Credit Corporation                  47
# 3     USDA - Federal Crop Insurance Corp Fund                   0
# 4                      USDA - Loan Repayments                  13
# 5                      Dept of Commerce (DOC)                  17
# 6                Dept of Defense (DoD) - misc                  52
# 7                                DoD - Health                  18
# 8                      Dept of Education (ED)                 169
# 9                        Dept of Energy (DOE)                  25
# 10   Dept of Health & Human Serv (HHS) - misc                  18
# 11                 HHS - Marketplace Receipts                   1
# 12                    HHS - Medicare Premiums                 283
# 13     Dept of Homeland Security (DHS) - misc                  34
# 14     DHS - Customs and Certain Excise Taxes                 149
# 15     DHS - Fed Emergency Mgmt Agency (FEMA)                  12
# 16                        DHS - Seized Assets                   1
# 17   DHS - Transportation Security Admn (TSA)                   2
# 18   Dept of Housing & Urban Dev (HUD) - misc                   4
# 19          HUD - Federal Housing Admin (FHA)                  46
# 20              Dept of Interior (DOI) - misc                   5
# 21          DOI - Fish and Wildlife and Parks                   2
# 22     DOI - Gas and Oil Lease Sales Proceeds                   7
# 23         DOI - Land and Minerals Management                   1
# 24                    DOI - Water and Science                   6
# 25                      Dept of Justice (DOJ)                  18
# 26                 Dept of Labor (DOL) - misc                   2
# 27       DOL - Pension Benefit Guaranty Corp.                   1
# 28                        Dept of State (DOS)                  13
# 29               Dept of Transportation (DOT)                   2
# 30            Dept of Treasury (TREAS) - misc                   1
# 31   TREAS - Bureau of Engraving and Printing                   0
# 32        TREAS - Comptroller of the Currency                   0
# 33             TREAS - Federal Financing Bank                   0
# 34                       TREAS - GSE Proceeds                   0
# 35                 TREAS - United States Mint                  35
# 36                   Taxes - Corporate Income                 396
# 37                    Taxes - Estate and Gift                  42
# 38        Taxes - Federal Unemployment (FUTA)                  34
# 39               Taxes - Miscellaneous Excise                 103
# 40   Taxes - Non Withheld Ind/SECA Electronic                 555
# 41        Taxes - Non Withheld Ind/SECA Other               11990
# 42                Taxes - Railroad Retirement                  61
# 43           Taxes - Withheld Individual/FICA                8351
# 44              Dept of Veterans Affairs (VA)                  27
# 45                       District of Columbia                   0
# 46      Environmental Protection Agency (EPA)                   3
# 47                         Export-Import Bank                   2
# 48    Federal Communications Commission (FCC)                   2
# 49               FCC - Universal Service Fund                   2
# 50      Federal Deposit Insurance Corp (FDIC)                   0
# 51                   Federal Reserve Earnings                   0
# 52     Federal Retirement Thrift Savings Plan                 271
# 53             Federal Trade Commission (FTC)                   1
# 54      General Services Administration (GSA)                   9
# 55                Independent Agencies - misc                  52
# 56          International Monetary Fund (IMF)                   0
# 57     Int'l Assistance Programs (IAP) - misc                   0
# 58   IAP - Agency for Int'l Development (AID)                   2
# 59               IAP - Foreign Military Sales                   4
# 60   IAP - US Int'l Devlop Finance Corp (DFC)                   5
# 61                   Judicial Branch - Courts                   4
# 62                  Legislative Branch - misc                   0
# 63   Legislative Branch - Library of Congress                   1
# 64         National Credit Union Admin (NCUA)                   0
# 65          National Science Foundation (NSF)                   0
# 66      Office of Personnel Mgmt (OPM) - misc                   0
# 67   OPM - Federal Employee Insurance Receipt                   0
# 68   RRB - Natl Railroad Retirement Inv Trust                   0
# 69               RRB - Unemployment Insurance                   0
# 70   Securities and Exchange Commission (SEC)                 188
# 71        Small Business Administration (SBA)                  64
# 72         Social Security Admin (SSA) - misc                   3
# 73         SSA - Supplemental Security Income                   2
# 74      State Unemployment Insurance Deposits                  93
# 75        United States Postal Service (USPS)                 346
# 76                 US Army Corps of Engineers                   6
# 77                    Unclassified - Deposits                   6
# 78       Public Debt Cash Issues (Table IIIB)                1655
# 79        Corporation for Public Broadcasting                   0
# 80          Dept of Agriculture (USDA) - misc                 122
# 81                     USDA - Child Nutrition                  68
# 82        USDA - Commodity Credit Corporation                  47
# 83    USDA - Federal Crop Insurance Corp Fund                 118
# 84                       USDA - Loan Payments                  83
# 85                  USDA - Other Farm Service                  49
# 86   USDA - Supp Nutrition Assist Prog (SNAP)                 320
# 87    USDA - Supp Nutrition Assist Prog (WIC)                  41
# 88                     Dept of Commerce (DOC)                  88
# 89               Dept of Defense (DoD) - misc                2366
# 90                               DoD - Health                 219
# 91             DoD - Military Active Duty Pay                  15
# 92                  DoD - Military Retirement                   1
# 93                     Dept of Education (ED)                1641
# 94                       Dept of Energy (DOE)                 356
# 95   Dept of Health & Human Serv (HHS) - misc                  60
# 96    HHS - Centers for Disease Control (CDC)                  56
# 97     HHS - Federal Hospital Insr Trust Fund                1083
# 98   HHS - Federal Supple Med Insr Trust Fund                 887
# 99        HHS - Grants to States for Medicaid                 903
# 100   HHS - Health Resources & Services Admin                  64
# 101               HHS - Indian Health Service                  12
# 102                HHS - Marketplace Payments                   0
# 103         HHS - Medicare Prescription Drugs                  10
# 104       HHS - National Institutes of Health                 212
# 105        HHS - Other Public Health Services                  53
# 106  HHS - Othr Admin for Children & Families                 142
# 107  HHS - Othr Cent Medicare & Medicaid Serv                  46
# 108                  HHS - Payments to States                  71
# 109  HHS - Temp Assistance for Needy Families                  54
# 110    Dept of Homeland Security (DHS) - misc                  89
# 111   DHS - Customs & Border Protection (CBP)                  85
# 112    DHS - Fed Emergency Mgmt Agency (FEMA)                 319
# 113  DHS - Transportation Security Admn (TSA)                  19
# 114  Dept of Housing & Urban Dev (HUD) - misc                 159
# 115         HUD - Federal Housing Admin (FHA)                  75
# 116             Dept of Interior (DOI) - misc                 106
# 117         DOI - Fish and Wildlife and Parks                  20
# 118        DOI - Land and Minerals Management                   7
# 119                   DOI - Water and Science                  36
# 120                     Dept of Justice (DOJ)                 159
# 121                Dept of Labor (DOL) - misc                 256
# 122      DOL - Pension Benefit Guaranty Corp.                   4
# 123               DOL - Unemployment Benefits                  74
# 124                       Dept of State (DOS)                  48
# 125       Dept of Transportation (DOT) - misc                  25
# 126     DOT - Federal Aviation Administration                  31
# 127      DOT - Federal Highway Administration                 291
# 128     DOT - Federal Railroad Administration                   1
# 129      DOT - Federal Transit Administration                  99
# 130           Dept of Treasury (TREAS) - misc                  75
# 131  TREAS - Bureau of Engraving and Printing                   0
# 132  TREAS - Claims Judgments and Relief Acts                  11
# 133       TREAS - Comptroller of the Currency                   3
# 134            TREAS - Federal Financing Bank                   6
# 135       TREAS - IRS Refunds for Puerto Rico                   5
# 136    TREAS - Pmt to Resolution Funding Corp                   0
# 137                TREAS - United States Mint                   5
# 138        Taxes - Business Tax Refunds (EFT)                   0
# 139      Taxes - Individual Tax Refunds (EFT)                   3
# 140          ESF - Economic Recovery Programs                   0
# 141             Dept of Veterans Affairs (VA)                 283
# 142                             VA - Benefits                 155
# 143              Taxes - IRS Collected Estate                  39
#
#      Transactions Month to Date  Transactions Fiscal Year to Date  \
# 0                          1109                              7452
# 1                           270                              1202
# 2                           573                              2147
# 3                             1                                18
# 4                           422                              2437
# 5                           753                              2035
# 6                          1018                              5440
# 7                           107                               695
# 8                          3942                             17401
# 9                           392                              2587
# 10                          351                              2579
# 11                           64                               204
# 12                         4112                             18676
# 13                          474                              2432
# 14                         2286                             27911
# 15                          182                              1028
# 16                           34                               205
# 17                          104                              1232
# 18                          465                              2068
# 19                         1354                              7530
# 20                           75                               501
# 21                           40                               210
# 22                           70                              3582
# 23                           51                               288
# 24                           94                               245
# 25                         1108                              4989
# 26                           28                               165
# 27                           40                              3942
# 28                          251                               963
# 29                          226                              1193
# 30                           77                               288
# 31                           37                               351
# 32                            0                               453
# 33                           15                              1369
# 34                            1                              1607
# 35                          481                              1525
# 36                        20656                            135068
# 37                         1385                              6866
# 38                          374                              1112
# 39                         3855                             28863
# 40                        76224                            127793
# 41                        48997                             85531
# 42                          456                              2128
# 43                       238051                           1083102
# 44                          469                              2485
# 45                            0                               102
# 46                           63                               190
# 47                           56                               589
# 48                           91                               521
# 49                          672                              2796
# 50                           36                              8909
# 51                          285                              1229
# 52                         5389                             13473
# 53                          100                               311
# 54                          118                               632
# 55                          190                              2937
# 56                          815                              3485
# 57                            0                                 2
# 58                           12                                45
# 59                         3525                             17199
# 60                          171                               730
# 61                           83                              1959
# 62                            3                                31
# 63                            4                                23
# 64                            1                               480
# 65                            1                                15
# 66                            0                                 2
# 67                          150                               604
# 68                          226                               473
# 69                            3                                16
# 70                          582                              1569
# 71                         1580                              7565
# 72                           51                               269
# 73                            4                               962
# 74                          717                              6254
# 75                         6397                             33006
# 76                           49                               363
# 77                          172                              1929
# 78                      2004104                          10035997
# 79                            0                               535
# 80                         1766                             10562
# 81                         2127                             10598
# 82                          889                              8193
# 83                         1945                             11518
# 84                          787                              4480
# 85                          268                               748
# 86                         7655                             35415
# 87                          500                              2468
# 88                         2464                              7857
# 89                        27539                            152237
# 90                         1936                              9433
# 91                         4018                             33717
# 92                          463                             23489
# 93                        28404                             75521
# 94                         4069                             20175
# 95                          579                              3336
# 96                          857                              4864
# 97                        29626                            132145
# 98                        39106                            176524
# 99                        41335                            199922
# 100                         712                              4445
# 101                        1044                              4598
# 102                        9860                             41296
# 103                       15492                             48373
# 104                        2494                             13947
# 105                         660                              3448
# 106                        1614                              8911
# 107                        2581                             20852
# 108                        2002                              9067
# 109                        1115                              5336
# 110                        1012                              5284
# 111                         731                              3561
# 112                        4674                             21491
# 113                         202                               846
# 114                        6125                             27476
# 115                        1126                              5194
# 116                         806                              5356
# 117                         443                              1868
# 118                         578                              1128
# 119                         543                              1421
# 120                        1601                              8108
# 121                        1195                              5748
# 122                         129                              3808
# 123                        2940                             11986
# 124                        1373                              7349
# 125                         299                              1649
# 126                         683                              4136
# 127                        4211                             20579
# 128                         764                              1668
# 129                        1227                              7270
# 130                         604                              4594
# 131                          12                               201
# 132                         276                              1765
# 133                          18                               125
# 134                        5785                             32183
# 135                          41                               319
# 136                         216                               460
# 137                         380                              1390
# 138                          98                              3584
# 139                         140                             20562
# 140                          50                             -1143
# 141                        6666                             33401
# 142                        1268                             64823
# 143                         285                              1182
#
#     Table Number                                  Table Name  \
# 0             II  Deposits and Withdrawals of Operating Cash
# 1             II  Deposits and Withdrawals of Operating Cash
# 2             II  Deposits and Withdrawals of Operating Cash
# 3             II  Deposits and Withdrawals of Operating Cash
# 4             II  Deposits and Withdrawals of Operating Cash
# 5             II  Deposits and Withdrawals of Operating Cash
# 6             II  Deposits and Withdrawals of Operating Cash
# 7             II  Deposits and Withdrawals of Operating Cash
# 8             II  Deposits and Withdrawals of Operating Cash
# 9             II  Deposits and Withdrawals of Operating Cash
# 10            II  Deposits and Withdrawals of Operating Cash
# 11            II  Deposits and Withdrawals of Operating Cash
# 12            II  Deposits and Withdrawals of Operating Cash
# 13            II  Deposits and Withdrawals of Operating Cash
# 14            II  Deposits and Withdrawals of Operating Cash
# 15            II  Deposits and Withdrawals of Operating Cash
# 16            II  Deposits and Withdrawals of Operating Cash
# 17            II  Deposits and Withdrawals of Operating Cash
# 18            II  Deposits and Withdrawals of Operating Cash
# 19            II  Deposits and Withdrawals of Operating Cash
# 20            II  Deposits and Withdrawals of Operating Cash
# 21            II  Deposits and Withdrawals of Operating Cash
# 22            II  Deposits and Withdrawals of Operating Cash
# 23            II  Deposits and Withdrawals of Operating Cash
# 24            II  Deposits and Withdrawals of Operating Cash
# 25            II  Deposits and Withdrawals of Operating Cash
# 26            II  Deposits and Withdrawals of Operating Cash
# 27            II  Deposits and Withdrawals of Operating Cash
# 28            II  Deposits and Withdrawals of Operating Cash
# 29            II  Deposits and Withdrawals of Operating Cash
# 30            II  Deposits and Withdrawals of Operating Cash
# 31            II  Deposits and Withdrawals of Operating Cash
# 32            II  Deposits and Withdrawals of Operating Cash
# 33            II  Deposits and Withdrawals of Operating Cash
# 34            II  Deposits and Withdrawals of Operating Cash
# 35            II  Deposits and Withdrawals of Operating Cash
# 36            II  Deposits and Withdrawals of Operating Cash
# 37            II  Deposits and Withdrawals of Operating Cash
# 38            II  Deposits and Withdrawals of Operating Cash
# 39            II  Deposits and Withdrawals of Operating Cash
# 40            II  Deposits and Withdrawals of Operating Cash
# 41            II  Deposits and Withdrawals of Operating Cash
# 42            II  Deposits and Withdrawals of Operating Cash
# 43            II  Deposits and Withdrawals of Operating Cash
# 44            II  Deposits and Withdrawals of Operating Cash
# 45            II  Deposits and Withdrawals of Operating Cash
# 46            II  Deposits and Withdrawals of Operating Cash
# 47            II  Deposits and Withdrawals of Operating Cash
# 48            II  Deposits and Withdrawals of Operating Cash
# 49            II  Deposits and Withdrawals of Operating Cash
# 50            II  Deposits and Withdrawals of Operating Cash
# 51            II  Deposits and Withdrawals of Operating Cash
# 52            II  Deposits and Withdrawals of Operating Cash
# 53            II  Deposits and Withdrawals of Operating Cash
# 54            II  Deposits and Withdrawals of Operating Cash
# 55            II  Deposits and Withdrawals of Operating Cash
# 56            II  Deposits and Withdrawals of Operating Cash
# 57            II  Deposits and Withdrawals of Operating Cash
# 58            II  Deposits and Withdrawals of Operating Cash
# 59            II  Deposits and Withdrawals of Operating Cash
# 60            II  Deposits and Withdrawals of Operating Cash
# 61            II  Deposits and Withdrawals of Operating Cash
# 62            II  Deposits and Withdrawals of Operating Cash
# 63            II  Deposits and Withdrawals of Operating Cash
# 64            II  Deposits and Withdrawals of Operating Cash
# 65            II  Deposits and Withdrawals of Operating Cash
# 66            II  Deposits and Withdrawals of Operating Cash
# 67            II  Deposits and Withdrawals of Operating Cash
# 68            II  Deposits and Withdrawals of Operating Cash
# 69            II  Deposits and Withdrawals of Operating Cash
# 70            II  Deposits and Withdrawals of Operating Cash
# 71            II  Deposits and Withdrawals of Operating Cash
# 72            II  Deposits and Withdrawals of Operating Cash
# 73            II  Deposits and Withdrawals of Operating Cash
# 74            II  Deposits and Withdrawals of Operating Cash
# 75            II  Deposits and Withdrawals of Operating Cash
# 76            II  Deposits and Withdrawals of Operating Cash
# 77            II  Deposits and Withdrawals of Operating Cash
# 78            II  Deposits and Withdrawals of Operating Cash
# 79            II  Deposits and Withdrawals of Operating Cash
# 80            II  Deposits and Withdrawals of Operating Cash
# 81            II  Deposits and Withdrawals of Operating Cash
# 82            II  Deposits and Withdrawals of Operating Cash
# 83            II  Deposits and Withdrawals of Operating Cash
# 84            II  Deposits and Withdrawals of Operating Cash
# 85            II  Deposits and Withdrawals of Operating Cash
# 86            II  Deposits and Withdrawals of Operating Cash
# 87            II  Deposits and Withdrawals of Operating Cash
# 88            II  Deposits and Withdrawals of Operating Cash
# 89            II  Deposits and Withdrawals of Operating Cash
# 90            II  Deposits and Withdrawals of Operating Cash
# 91            II  Deposits and Withdrawals of Operating Cash
# 92            II  Deposits and Withdrawals of Operating Cash
# 93            II  Deposits and Withdrawals of Operating Cash
# 94            II  Deposits and Withdrawals of Operating Cash
# 95            II  Deposits and Withdrawals of Operating Cash
# 96            II  Deposits and Withdrawals of Operating Cash
# 97            II  Deposits and Withdrawals of Operating Cash
# 98            II  Deposits and Withdrawals of Operating Cash
# 99            II  Deposits and Withdrawals of Operating Cash
# 100           II  Deposits and Withdrawals of Operating Cash
# 101           II  Deposits and Withdrawals of Operating Cash
# 102           II  Deposits and Withdrawals of Operating Cash
# 103           II  Deposits and Withdrawals of Operating Cash
# 104           II  Deposits and Withdrawals of Operating Cash
# 105           II  Deposits and Withdrawals of Operating Cash
# 106           II  Deposits and Withdrawals of Operating Cash
# 107           II  Deposits and Withdrawals of Operating Cash
# 108           II  Deposits and Withdrawals of Operating Cash
# 109           II  Deposits and Withdrawals of Operating Cash
# 110           II  Deposits and Withdrawals of Operating Cash
# 111           II  Deposits and Withdrawals of Operating Cash
# 112           II  Deposits and Withdrawals of Operating Cash
# 113           II  Deposits and Withdrawals of Operating Cash
# 114           II  Deposits and Withdrawals of Operating Cash
# 115           II  Deposits and Withdrawals of Operating Cash
# 116           II  Deposits and Withdrawals of Operating Cash
# 117           II  Deposits and Withdrawals of Operating Cash
# 118           II  Deposits and Withdrawals of Operating Cash
# 119           II  Deposits and Withdrawals of Operating Cash
# 120           II  Deposits and Withdrawals of Operating Cash
# 121           II  Deposits and Withdrawals of Operating Cash
# 122           II  Deposits and Withdrawals of Operating Cash
# 123           II  Deposits and Withdrawals of Operating Cash
# 124           II  Deposits and Withdrawals of Operating Cash
# 125           II  Deposits and Withdrawals of Operating Cash
# 126           II  Deposits and Withdrawals of Operating Cash
# 127           II  Deposits and Withdrawals of Operating Cash
# 128           II  Deposits and Withdrawals of Operating Cash
# 129           II  Deposits and Withdrawals of Operating Cash
# 130           II  Deposits and Withdrawals of Operating Cash
# 131           II  Deposits and Withdrawals of Operating Cash
# 132           II  Deposits and Withdrawals of Operating Cash
# 133           II  Deposits and Withdrawals of Operating Cash
# 134           II  Deposits and Withdrawals of Operating Cash
# 135           II  Deposits and Withdrawals of Operating Cash
# 136           II  Deposits and Withdrawals of Operating Cash
# 137           II  Deposits and Withdrawals of Operating Cash
# 138           II  Deposits and Withdrawals of Operating Cash
# 139           II  Deposits and Withdrawals of Operating Cash
# 140           II  Deposits and Withdrawals of Operating Cash
# 141           II  Deposits and Withdrawals of Operating Cash
# 142           II  Deposits and Withdrawals of Operating Cash
# 143           II  Deposits and Withdrawals of Operating Cash
#
#     Source Line Number Fiscal Year Fiscal Quarter Number Calendar Year  \
# 0                  167        2025                     2          2025
# 1                    1        2025                     2          2025
# 2                    2        2025                     2          2025
# 3                    3        2025                     2          2025
# 4                    4        2025                     2          2025
# 5                    5        2025                     2          2025
# 6                    6        2025                     2          2025
# 7                    7        2025                     2          2025
# 8                    8        2025                     2          2025
# 9                    9        2025                     2          2025
# 10                  10        2025                     2          2025
# 11                  11        2025                     2          2025
# 12                  12        2025                     2          2025
# 13                  13        2025                     2          2025
# 14                  14        2025                     2          2025
# 15                  15        2025                     2          2025
# 16                  16        2025                     2          2025
# 17                  17        2025                     2          2025
# 18                  18        2025                     2          2025
# 19                  19        2025                     2          2025
# 20                  20        2025                     2          2025
# 21                  21        2025                     2          2025
# 22                  22        2025                     2          2025
# 23                  23        2025                     2          2025
# 24                  24        2025                     2          2025
# 25                  25        2025                     2          2025
# 26                  26        2025                     2          2025
# 27                  27        2025                     2          2025
# 28                  28        2025                     2          2025
# 29                  29        2025                     2          2025
# 30                  30        2025                     2          2025
# 31                  31        2025                     2          2025
# 32                  32        2025                     2          2025
# 33                  33        2025                     2          2025
# 34                  34        2025                     2          2025
# 35                  35        2025                     2          2025
# 36                  36        2025                     2          2025
# 37                  37        2025                     2          2025
# 38                  38        2025                     2          2025
# 39                  40        2025                     2          2025
# 40                  41        2025                     2          2025
# 41                  42        2025                     2          2025
# 42                  43        2025                     2          2025
# 43                  44        2025                     2          2025
# 44                  45        2025                     2          2025
# 45                  46        2025                     2          2025
# 46                  47        2025                     2          2025
# 47                  48        2025                     2          2025
# 48                  49        2025                     2          2025
# 49                  50        2025                     2          2025
# 50                  51        2025                     2          2025
# 51                  52        2025                     2          2025
# 52                  53        2025                     2          2025
# 53                  54        2025                     2          2025
# 54                  55        2025                     2          2025
# 55                  56        2025                     2          2025
# 56                  57        2025                     2          2025
# 57                  58        2025                     2          2025
# 58                  59        2025                     2          2025
# 59                  60        2025                     2          2025
# 60                  61        2025                     2          2025
# 61                  62        2025                     2          2025
# 62                  63        2025                     2          2025
# 63                  64        2025                     2          2025
# 64                  65        2025                     2          2025
# 65                  66        2025                     2          2025
# 66                  67        2025                     2          2025
# 67                  68        2025                     2          2025
# 68                  69        2025                     2          2025
# 69                  70        2025                     2          2025
# 70                  71        2025                     2          2025
# 71                  72        2025                     2          2025
# 72                  73        2025                     2          2025
# 73                  74        2025                     2          2025
# 74                  75        2025                     2          2025
# 75                  76        2025                     2          2025
# 76                  77        2025                     2          2025
# 77                  78        2025                     2          2025
# 78                  80        2025                     2          2025
# 79                  82        2025                     2          2025
# 80                  83        2025                     2          2025
# 81                  84        2025                     2          2025
# 82                  85        2025                     2          2025
# 83                  86        2025                     2          2025
# 84                  87        2025                     2          2025
# 85                  88        2025                     2          2025
# 86                  89        2025                     2          2025
# 87                  90        2025                     2          2025
# 88                  91        2025                     2          2025
# 89                  92        2025                     2          2025
# 90                  93        2025                     2          2025
# 91                  94        2025                     2          2025
# 92                  95        2025                     2          2025
# 93                  96        2025                     2          2025
# 94                  97        2025                     2          2025
# 95                  98        2025                     2          2025
# 96                  99        2025                     2          2025
# 97                 100        2025                     2          2025
# 98                 101        2025                     2          2025
# 99                 102        2025                     2          2025
# 100                103        2025                     2          2025
# 101                104        2025                     2          2025
# 102                105        2025                     2          2025
# 103                106        2025                     2          2025
# 104                107        2025                     2          2025
# 105                108        2025                     2          2025
# 106                109        2025                     2          2025
# 107                110        2025                     2          2025
# 108                111        2025                     2          2025
# 109                112        2025                     2          2025
# 110                113        2025                     2          2025
# 111                114        2025                     2          2025
# 112                115        2025                     2          2025
# 113                116        2025                     2          2025
# 114                117        2025                     2          2025
# 115                118        2025                     2          2025
# 116                119        2025                     2          2025
# 117                120        2025                     2          2025
# ...
# 104                       1                     1                  24
# 105                       1                     1                  24
# 106                       1                     1                  24
# 107                       1                     1                  24
# 108                       1                     1                  24
# 109                       1                     1                  24
# 110                       1                     1                  24
# 111                       1                     1                  24
# 112                       1                     1                  24
# 113                       1                     1                  24
# 114                       1                     1                  24
# 115                       1                     1                  24
# 116                       1                     1                  24
# 117                       1                     1                  24
# 118                       1                     1                  24
# 119                       1                     1                  24
# 120                       1                     1                  24
# 121                       1                     1                  24
# 122                       1                     1                  24
# 123                       1                     1                  24
# 124                       1                     1                  24
# 125                       1                     1                  24
# 126                       1                     1                  24
# 127                       1                     1                  24
# 128                       1                     1                  24
# 129                       1                     1                  24
# 130                       1                     1                  24
# 131                       1                     1                  24
# 132                       1                     1                  24
# 133                       1                     1                  24
# 134                       1                     1                  24
# 135                       1                     1                  24
# 136                       1                     1                  24
# 137                       1                     1                  24
# 138                       1                     1                  24
# 139                       1                     1                  24
# 140                       1                     1                  24
# 141                       1                     1                  24
# 142                       1                     1                  24
# 143                       1                    01                  24
#
#      (Withdrawal Percentage by Fiscal YTD,)  \
# 0                                  0.532418
# 1                                  0.754616
# 2                                  0.585360
# 3                                  0.822919
# 4                                       NaN
# 5                                  0.561354
# 6                                 10.876775
# 7                                  0.673953
# 8                                  5.395698
# 9                                  1.441430
# 10                                 0.238345
# 11                                      NaN
# 12                                      NaN
# 13                                 0.377522
# 14                                      NaN
# 15                                 1.535453
# 16                                      NaN
# 17                                 0.060444
# 18                                 1.963059
# 19                                 0.371092
# 20                                 0.382667
# 21                                 0.133462
# 22                                      NaN
# 23                                 0.080591
# 24                                 0.101525
# 25                                 0.579287
# 26                                 0.410674
# 27                                 0.272068
# 28                                 0.525059
# 29                                      NaN
# 30                                 0.328224
# 31                                 0.014361
# 32                                 0.008931
# 33                                 2.299357
# 34                                      NaN
# 35                                 0.099310
# 36                                      NaN
# 37                                      NaN
# 38                                      NaN
# 39                                      NaN
# 40                                      NaN
# 41                                      NaN
# 42                                      NaN
# 43                                      NaN
# 44                                 2.386379
# 45                                      NaN
# 46                                      NaN
# 47                                      NaN
# 48                                      NaN
# 49                                      NaN
# 50                                      NaN
# 51                                      NaN
# 52                                      NaN
# 53                                      NaN
# 54                                      NaN
# 55                                      NaN
# 56                                      NaN
# 57                                      NaN
# 58                                      NaN
# 59                                      NaN
# 60                                      NaN
# 61                                      NaN
# 62                                      NaN
# 63                                      NaN
# 64                                      NaN
# 65                                      NaN
# 66                                      NaN
# 67                                      NaN
# 68                                      NaN
# 69                                      NaN
# 70                                      NaN
# 71                                      NaN
# 72                                      NaN
# 73                                      NaN
# 74                                      NaN
# 75                                      NaN
# 76                                      NaN
# 77                                      NaN
# 78                                      NaN
# 79                                 0.038224
# 80                                 0.754616
# 81                                 0.757188
# 82                                 0.585360
# 83                                 0.822919
# 84                                 0.320080
# 85                                 0.053442
# 86                                 2.530272
# 87                                 0.176330
# 88                                 0.561354
# 89                                10.876775
# 90                                 0.673953
# 91                                 2.408956
# 92                                 1.678203
# 93                                 5.395698
# 94                                 1.441430
# 95                                 0.238345
# 96                                 0.347515
# 97                                 9.441275
# 98                                12.611992
# 99                                14.283693
# 100                                0.317579
# 101                                0.328510
# 102                                2.950448
# 103                                3.456073
# 104                                0.996462
# 105                                0.246347
# 106                                0.636658
# 107                                1.489799
# 108                                0.647804
# 109                                0.381238
# 110                                0.377522
# 111                                0.254420
# 112                                1.535453
# 113                                0.060444
# 114                                1.963059
# 115                                0.371092
# 116                                0.382667
# 117                                0.133462
# 118                                0.080591
# 119                                0.101525
# 120                                0.579287
# 121                                0.410674
# 122                                0.272068
# 123                                0.856356
# 124                                0.525059
# 125                                0.117815
# 126                                0.295502
# 127                                1.470294
# 128                                0.119172
# 129                                0.519415
# 130                                0.328224
# 131                                0.014361
# 132                                0.126103
# 133                                0.008931
# 134                                2.299357
# 135                                0.022791
# 136                                0.032865
# 137                                0.099310
# 138                                0.256064
# 139                                1.469079
# 140                               -0.081663
# 141                                2.386379
# 142                                4.631366
# 143                                     NaN
#
#      (Deposit Percentage by Fiscal YTD,)
# 0                                    NaN
# 1                               0.010240
# 2                               0.018291
# 3                               0.000153
# 4                               0.020761
# 5                               0.017336
# 6                               0.046344
# 7                               0.005921
# 8                               0.148241
# 9                               0.022039
# 10                              0.021971
# 11                              0.001738
# 12                              0.159103
# 13                              0.020719
# 14                              0.237777
# 15                              0.008758
# 16                              0.001746
# 17                              0.010496
# 18                              0.017618
# 19                              0.064149
# 20                              0.004268
# 21                              0.001789
# 22                              0.030516
# 23                              0.002454
# 24                              0.002087
# 25                              0.042502
# 26                              0.001406
# 27                              0.033582
# 28                              0.008204
# 29                              0.010163
# 30                              0.002454
# 31                              0.002990
# 32                              0.003859
# 33                              0.011663
# 34                              0.013690
# 35                              0.012992
# 36                              1.150661
# 37                              0.058492
# 38                              0.009473
# 39                              0.245887
# 40                              1.088685
# 41                              0.728649
# 42                              0.018129
# 43                              9.227081
# 44                              0.021170
# 45                              0.000869
# 46                              0.001619
# 47                              0.005018
# 48                              0.004438
# 49                              0.023819
# 50                              0.075897
# 51                              0.010470
# 52                              0.114778
# 53                              0.002649
# 54                              0.005384
# 55                              0.025021
# 56                              0.029689
# 57                              0.000017
# 58                              0.000383
# 59                              0.146520
# 60                              0.006219
# 61                              0.016689
# 62                              0.000264
# 63                              0.000196
# 64                              0.004089
# 65                              0.000128
# 66                              0.000017
# 67                              0.005146
# 68                              0.004030
# 69                              0.000136
# 70                              0.013367
# 71                              0.064447
# 72                              0.002292
# 73                              0.008195
# 74                              0.053279
# 75                              0.281182
# 76                              0.003092
# 77                              0.016433
# 78                             85.497911
# 79                                   NaN
# 80                              0.010240
# 81                                   NaN
# 82                              0.018291
# 83                              0.000153
# 84                                   NaN
# 85                                   NaN
# 86                                   NaN
# 87                                   NaN
# 88                              0.017336
# 89                              0.046344
# 90                              0.005921
# 91                                   NaN
# 92                                   NaN
# 93                              0.148241
# 94                              0.022039
# 95                              0.021971
# 96                                   NaN
# 97                                   NaN
# 98                                   NaN
# 99                                   NaN
# 100                                  NaN
# 101                                  NaN
# 102                                  NaN
# 103                                  NaN
# 104                                  NaN
# 105                                  NaN
# 106                                  NaN
# 107                                  NaN
# 108                                  NaN
# 109                                  NaN
# 110                             0.020719
# 111                                  NaN
# 112                             0.008758
# 113                             0.010496
# 114                             0.017618
# 115                             0.064149
# 116                             0.004268
# 117                             0.001789
# 118                             0.002454
# 119                             0.002087
# 120                             0.042502
# 121                             0.001406
# 122                             0.033582
# 123                                  NaN
# 124                             0.008204
# 125                                  NaN
# 126                                  NaN
# 127                                  NaN
# 128                                  NaN
# 129                                  NaN
# 130                             0.002454
# 131                             0.002990
# 132                                  NaN
# 133                             0.003859
# 134                             0.011663
# 135                                  NaN
# 136                                  NaN
# 137                             0.012992
# 138                                  NaN
# 139                                  NaN
# 140                                  NaN
# 141                             0.021170
# 142                                  NaN
# 143                             0.010070
